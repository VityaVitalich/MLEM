# %%
import pandas as pd

# %%
df = pd.read_parquet('../data/train.parquet/')

# %%
df['target'].value_counts()
# Out:
# target
# 3    6027
# 1    6006
# 2    6005
# 0    5962
# Name: count, dtype: int64

# %%
test = pd.read_parquet('../data/test.parquet/')

# %%
test['target'].value_counts()
# Out:
# target
# 2    1555
# 1    1491
# 3    1482
# 0    1472
# Name: count, dtype: int64

# %%
test
# Out:
#       client_id                                         event_time  \
# 0           580  [0.0, 0.0013717421124828531, 0.001371742112482...
# 1           613  [0.009602194787379973, 0.010973936899862825, 0...
# 2           970  [0.0013717421124828531, 0.00411522633744856, 0...
# 3          1903  [0.0, 0.0013717421124828531, 0.002743484224965...
# 4          2142  [0.0027434842249657062, 0.0027434842249657062,...
# ...         ...                                                ...
# 5995      38521  [0.0, 0.0, 0.0013717421124828531, 0.0013717421...
# 5996      38816  [0.0013717421124828531, 0.0027434842249657062,...
# 5997      41224  [0.0013717421124828531, 0.00411522633744856, 0...
# 5998      42301  [0.01646090534979424, 0.01783264746227709, 0.0...
# 5999      48983  [0.0027434842249657062, 0.00411522633744856, 0...
#
#                                              amount_rur  \
# 0     [4.1768304367775295, 2.735989569791452, 3.1544...
# ...

# %%
df['small_group'].apply(max).max()
# Out:
# 201

# %%
test['small_group'].apply(max).max()
# Out:
# 198
